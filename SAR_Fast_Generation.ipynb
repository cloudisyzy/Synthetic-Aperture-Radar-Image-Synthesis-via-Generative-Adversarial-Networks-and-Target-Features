# %% [markdown]
# Run this programme to generate SAR images based on trained GAN parameters. Just run the whole code and follow instructions

# %%
from __utils.SAR_fast_generation import fast_SAR_generation
import os
os.environ['KMP_DUPLICATE_LIB_OK']="True"

fast_SAR_generation()
# Out:
# Model List [ 0:DCGAN, 1:WGAN-GP, 2:WGAN-DIV, 3:SNGAN, 4:SNGAN(Enhanced), 5:VAE-GAN ]
# Please enter the model number:  2
# SAR Image Category List [ 0:2S1, 1:BMP2, 2:BRDM2, 3:BTR60, 4:BTR70, 5:D7, 6:T62, 7:T72, 8:ZIL131, 9:ZSU234 ]
# Please enter the category number:  0
# Please enter how many number of images to be generated:  9
# Please enter the dpi of plotted figure, 200 is recommended, the more images generated, the higher dpi:  400
# Generate 9 2S1 images from WGAN-DIV, dpi=400
